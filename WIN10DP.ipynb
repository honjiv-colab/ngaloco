# %% [markdown]
# <a href="https://colab.research.google.com/github/honjiv-colab/ngaloco/blob/main/WIN10DP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scrip By An Bui

# %% [markdown]
# GitHub: https://github.com/AnBui2004/Qemu-Google-Colab-Tiny-10.git

# %% [markdown]
# If you have a problem. Let's join the Discord server: https://discord.gg/CBr7vqvzhR

# %% [markdown]
# First, create ngrok account and copy your token here: https://dashboard.ngrok.com/get-started/your-authtoken

# %%
#@title **Setup ngrok**


#@markdown **Please enter your ngrok token here before running**
#@markdown ****
#@markdown It doesn't take too long
import os
YOURTOKEN = "30jZNWi8WWE1RqsBndXDM1sPAJM_4NjdvC8Z6vfxv6P9XoJLB" #@param {type:"string"}

if YOURTOKEN == "":
            print("Please enter your token")
elif len(str(YOURTOKEN)) < 49:
   print("Your ngrok token is invalid. Please check back")
elif len(str(YOURTOKEN)) > 49:
   print("Your ngrok token is invalid. Please check back")
else:
  print("Installing ngrok...")
  os.system("wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz")
  os.system("tar zxvf -o ngrok-v3-stable-linux-amd64.tgz > /dev/null 2>&1")
  os.system("rm -rf ngrok-v3-stable-linux-amd64.tgz")
  print("Setting up...")
  os.system(f"./ngrok authtoken {YOURTOKEN}")
  os.system("nohup ./ngrok tcp --region ap 5900 &>/dev/null &")
  print("Done")

# %% [markdown]
# After completing the above step, run the code below to get started:

# %% [markdown]
# Download and install the VNC Viewer application here to connect to the virtual machine and use it: https://www.realvnc.com/en/connect/download/viewer/

# %% [markdown]
# Note: The E drive also contains the Firefox browser installer.

# %%
#@title **Tiny10**


#@markdown **Please use VNC Viewer to connect**
#@markdown ****
#@markdown It takes about 3 minutes to get started
# !wget -O Win.sh https://raw.githubusercontent.com/AnBui2004/Qemu-Google-Colab-Tiny-10/main/Run10.sh 2>&1
# !chmod +x Win.sh
# !./Win.sh
# Out:
# --2025-08-02 13:55:16--  https://raw.githubusercontent.com/AnBui2004/Qemu-Google-Colab-Tiny-10/main/Run10.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 724 [text/plain]
# Saving to: ‘Win.sh’
#
# Win.sh              100%[===================>]     724  --.-KB/s    in 0s
#
# 2025-08-02 13:55:16 (89.6 MB/s) - ‘Win.sh’ saved [724/724]
#
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,853 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# ...

# %%
#@title **Tiny10 (Install with ISO)**


#@markdown **Please use VNC Viewer to connect**
#@markdown ****
#@markdown It takes about 5 minutes to get started
# !wget -O Win.sh https://raw.githubusercontent.com/AnBui2004/Qemu-Google-Colab-Tiny-10/main/Run1.sh 2>&1
# !chmod +x Win.sh
# !./Win.sh

# %% [markdown]
# If you choose to install with ISO, watch this video to skip OOBE: https://www.youtube.com/watch?v=H-fKv-ZMFeA&t=58s

# %% [markdown]
# If having problems, try with this:

# %%
#@title **Tiny10 (Longer setup time)**


#@markdown **Please use VNC Viewer to connect**
#@markdown ****
#@markdown It takes about 30 minutes to get started
# !wget -O Win.sh https://raw.githubusercontent.com/AnBui2004/Qemu-Google-Colab-Tiny-10/main/Run11.sh 2>&1
# !chmod +x Win.sh
# !./Win.sh

# %% [markdown]
# 3. Turn it back on if you turned it off by mistake:

# %% [markdown]
# Please run ngrok setup again before running this

# %%
#@title **Turn on the virtual machine again**


#@markdown ***Only works if you turn it off by mistake and the runtime is still there***
#@markdown ****
#@markdown A new VNC address will be created
# !wget -O Win.sh https://raw.githubusercontent.com/AnBui2004/Qemu-Google-Colab-Tiny-10/main/Run3.sh > /dev/null 2>&1
# !chmod +x Win.sh
# !./Win.sh
